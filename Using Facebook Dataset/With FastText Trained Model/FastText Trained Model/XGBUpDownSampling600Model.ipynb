# %%
import string
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import gensim 

from sklearn.decomposition import PCA
from gensim.models import FastText as FT_gensim
from gensim.test.utils import datapath
from gensim.models.wrappers import FastText as FT

# %matplotlib inline
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\egapa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_excel("../pemilu.xlsx")
df
# Out:
#            id_pembuat                        id_status           nama_pembuat  \
# 0         23383061178    23383061178_10152076252911179             Bang Nafie
# 1         23383061178    23383061178_10152076252911179   Sumy Kakasyi Suhaimy
# 2         23383061178    23383061178_10152076252911179            Roberto Red
# 3         23383061178    23383061178_10152076252911179        Sugiarman Arman
# 4         23383061178    23383061178_10152076252911179       Rio Corps Taruna
# ...               ...                              ...                    ...
# 3359  249750628565406  249750628565406_276917339182068           Anita Rizkia
# 3360  249750628565406  249750628565406_276917339182068      Ari Bin Abu Bakar
# 3361  249750628565406  249750628565406_276917339182068             Agek James
# 3362  249750628565406  249750628565406_276917339182068  ChairudinDr Humaniora
# 3363  249750628565406  249750628565406_276917339182068    Wahyu Setyo Nugroho
#
#                                             teks_status  \
# 0     Saya banyak belajar prinsip-prinsip kehidupan ...
# 1     Saya banyak belajar prinsip-prinsip kehidupan ...
# 2     Saya banyak belajar prinsip-prinsip kehidupan ...
# 3     Saya banyak belajar prinsip-prinsip kehidupan ...
# 4     Saya banyak belajar prinsip-prinsip kehidupan ...
# ...                                                 ...
# 3359  Dukungan anda semua adalah amanah, dan apapun ...
# 3360  Dukungan anda semua adalah amanah, dan apapun ...
# 3361  Dukungan anda semua adalah amanah, dan apapun ...
# 3362  Dukungan anda semua adalah amanah, dan apapun ...
# 3363  Dukungan anda semua adalah amanah, dan apapun ...
#
#                                           gambar_status  \
# 0     https://fbexternal-a.akamaihd.net/safe_image.p...
# 1     https://fbexternal-a.akamaihd.net/safe_image.p...
# 2     https://fbexternal-a.akamaihd.net/safe_image.p...
# 3     https://fbexternal-a.akamaihd.net/safe_image.p...
# 4     https://fbexternal-a.akamaihd.net/safe_image.p...
# ...                                                 ...
# 3359  https://fbexternal-a.akamaihd.net/safe_image.p...
# 3360  https://fbexternal-a.akamaihd.net/safe_image.p...
# 3361  https://fbexternal-a.akamaihd.net/safe_image.p...
# 3362  https://fbexternal-a.akamaihd.net/safe_image.p...
# 3363  https://fbexternal-a.akamaihd.net/safe_image.p...
#
#                                            url_komentar        waktu_status  \
# 0     https://www.facebook.com/23383061178/posts/101... 2014-06-05 03:54:47
# 1     https://www.facebook.com/23383061178/posts/101... 2014-06-05 03:54:47
# 2     https://www.facebook.com/23383061178/posts/101... 2014-06-05 03:54:47
# 3     https://www.facebook.com/23383061178/posts/101... 2014-06-05 03:54:47
# 4     https://www.facebook.com/23383061178/posts/101... 2014-06-05 03:54:47
# ...                                                 ...                 ...
# 3359  https://www.facebook.com/249750628565406/posts... 2014-07-09 03:19:51
# 3360  https://www.facebook.com/249750628565406/posts... 2014-07-09 03:19:51
# 3361  https://www.facebook.com/249750628565406/posts... 2014-07-09 03:19:51
# 3362  https://www.facebook.com/249750628565406/posts... 2014-07-09 03:19:51
# 3363  https://www.facebook.com/249750628565406/posts... 2014-07-09 03:19:51
#
#                               id_komentar      id_user_komen  \
# 0     10152076252516179_10152076253441179    794948677210695
# 1     10152076252516179_10152076253906179    355122887988412
# 2     10152076252516179_10152076253996179    297825977080553
# 3     10152076252516179_10152076254066179    298708870333739
# 4     10152076252516179_10152076254216179   1523715244533780
# ...                                   ...                ...
# 3359      276891429184659_276927652514370    967613349931842
# 3360      276891429184659_276918865848582    773356856051191
# 3361      276891429184659_276921042515031    710343512387954
# 3362      276891429184659_276931322514003  10152763210314600
# 3363      276891429184659_276918872515248    830713220314118
#
#                                                komentar         waktu_komen  \
# 0                                        Oke pak boss!! 2014-06-05 03:55:15
# 1                                          Jangan dusta 2014-06-05 03:55:29
# 2                  PROBOWO is the WINNER of PEMILU 2014 2014-06-05 03:55:32
# 3                                             ilmu padi 2014-06-05 03:55:35
# 4                                  Hidup Pak Prabowo .. 2014-06-05 03:55:42
# ...                                                 ...                 ...
# 3359                                       salam 2 jari 2014-07-09 03:25:45
# 3360  Jujur, ketika Ane membuka Surat Suara tadi, An... 2014-07-09 03:21:40
# 3361  BAPAK JOKOWI KAMI SEMUA RAKYAT INGIN BAPAK JD ... 2014-07-09 03:24:02
# 3362  Tanda2 alam, pemilu 2day on  9 Juli (9-7= 2) ,... 2014-07-09 03:26:36
# 3363  Dosa dosa Prabowo\n admin  Tolak Lupa\n1. Mari... 2014-07-09 03:21:40
#
#         label
# 0     positif
# 1     negatif
# 2     positif
# 3      netral
# 4     positif
# ...       ...
# 3359  positif
# 3360  negatif
# 3361  positif
# 3362  positif
# 3363  positif
#
# [3364 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.2, random_state=1)

df_pos = df_train[df_train['label'] == 'positif']
df_pos_train, df_pos_test = train_test_split(df_pos, test_size=0.75, random_state=1)

df_neg = df_train[df_train['label'] == 'negatif']
df_net = df_train[df_train['label'] == 'netral']

# %%
df_neg_up = df_neg
df_net_up = df_net

# %%
for a in range(2):
    df_neg = df_neg.append(df_neg_up)

for a in range(7):
    df_net = df_net.append(df_net_up)

# %%
df_UpDownSampling = df_pos_train.append(df_neg)
df_UpDownSampling = df_UpDownSampling.append(df_net)
df_UpDownSampling = df_UpDownSampling.dropna()
df_UpDownSampling
# Out:
#            id_pembuat                        id_status  \
# 810       23383061178    23383061178_10152127986336179
# 60        23383061178    23383061178_10152079089271179
# 2195  249750628565406  249750628565406_254960948044374
# 1438      23383061178    23383061178_10152169415911179
# 1708  249750628565406  249750628565406_250565948483874
# ...               ...                              ...
# 2254  249750628565406  249750628565406_255802404626895
# 63        23383061178    23383061178_10152079089271179
# 3315  249750628565406  249750628565406_276917339182068
# 15        23383061178    23383061178_10152076252911179
# 3115  249750628565406  249750628565406_270928309780971
#
#                  nama_pembuat  \
# 810   Alvino Blackburoutsider
# 60               Rumah Pulang
# 2195              AÃ±Ã± MÃ«Ã«
# 1438             Anton Sadewa
# 1708         Mokhamad Haryadi
# ...                       ...
# 2254             Janz Piliang
# 63                Vendra Nosa
# 3315           ???G? d???????
# 15       Danny Charles Carter
# 3115      Nico Nyolee Jr Gong
#
#                                             teks_status  \
# 810   Kelemahan terbesar saya, adalah saya tidak bis...
# 60    Sahabat, hari ini saya kembali berkeliling Jaw...
# 2195  Poin-poin Visi dan Rencana Aksi untuk mencapai...
# 1438  Selamat pagi menjelang siang, ibu Lady Diana W...
# 1708  Rabu malam lalu, saya memberikan pemaparan dal...
# ...                                                 ...
# 2254  Selamat siang, saudara-saudaraku dan selamat b...
# 63    Sahabat, hari ini saya kembali berkeliling Jaw...
# 3315  Dukungan anda semua adalah amanah, dan apapun ...
# 15    Saya banyak belajar prinsip-prinsip kehidupan ...
# 3115  Selfie dulu dengan Pak JK sebelum persiapan de...
#
#                                           gambar_status  \
# 810   https://fbexternal-a.akamaihd.net/safe_image.p...
# 60    https://fbexternal-a.akamaihd.net/safe_image.p...
# 2195  https://fbexternal-a.akamaihd.net/safe_image.p...
# 1438  https://fbexternal-a.akamaihd.net/safe_image.p...
# 1708  https://fbexternal-a.akamaihd.net/safe_image.p...
# ...                                                 ...
# 2254  https://fbexternal-a.akamaihd.net/safe_image.p...
# 63    https://fbexternal-a.akamaihd.net/safe_image.p...
# 3315  https://fbexternal-a.akamaihd.net/safe_image.p...
# 15    https://fbexternal-a.akamaihd.net/safe_image.p...
# 3115  https://fbexternal-a.akamaihd.net/safe_image.p...
#
#                                            url_komentar        waktu_status  \
# 810   https://www.facebook.com/23383061178/posts/101... 2014-06-23 14:31:44
# 60    https://www.facebook.com/23383061178/posts/101... 2014-06-06 11:28:29
# 2195  https://www.facebook.com/249750628565406/posts... 2014-06-16 04:57:32
# 1438  https://www.facebook.com/23383061178/posts/101... 2014-07-06 03:15:06
# 1708  https://www.facebook.com/249750628565406/posts... 2014-06-06 09:29:23
# ...                                                 ...                 ...
# 2254  https://www.facebook.com/249750628565406/posts... 2014-06-17 05:19:26
# 63    https://www.facebook.com/23383061178/posts/101... 2014-06-06 11:28:29
# 3315  https://www.facebook.com/249750628565406/posts... 2014-07-09 03:19:51
# 15    https://www.facebook.com/23383061178/posts/101... 2014-06-05 03:54:47
# 3115  https://www.facebook.com/249750628565406/posts... 2014-07-05 03:41:20
#
#                               id_komentar      id_user_komen  \
# 810   10152127932471179_10152127997286179    296394710558882
# 60    10152079082881179_10152079092456179    797510576979808
# 2195      254960528044416_254965971377205   1494991287425680
# 1438  10152169415911179_10152169422261179    761946230511024
# 1708      250565948483874_250617085145427    836002496420338
# ...                                   ...                ...
# 2254      255802077960261_255831244624011    936516416363623
# 63    10152079082881179_10152079095236179    920854587942188
# 3315      276891429184659_276917629182039    731104776965641
# 15    10152076252516179_10152076256206179  10201658144535000
# 3115      270924516448017_270928699780932    943017389044925
#
#                                                komentar         waktu_komen  \
# 810   Mari Kita dukung H. Joko widodo Tetap menjadi ... 2014-06-23 14:33:49
# 60                  kalau ada nomor 1 untuk apa nomor 2 2014-06-06 11:30:22
# 2195  mantap Lanjut kan pak,suara rakyat yg rindu pe... 2014-06-16 05:04:23
# 1438                                              Amin. 2014-07-06 03:16:16
# 1708  Niat baik, Insya Allah hasilnya baik. Luruskan... 2014-06-06 10:27:47
# ...                                                 ...                 ...
# 2254                                     Ni kalo jomblo 2014-06-17 05:53:08
# 63                               Ke padang kapan pak..? 2014-06-06 11:31:19
# 3315  [[491100850982673]]\n??B-) foto ?? nya ?? itu ... 2014-07-09 03:20:15
# 15                                   Duh gagal pertamax 2014-06-05 03:56:45
# 3115                                          #BEJO4RI1 2014-07-05 03:41:46
#
#         label
# 810   positif
# 60    positif
# 2195  positif
# 1438  positif
# 1708  positif
# ...       ...
# 2254   netral
# 63     netral
# 3315   netral
# 15     netral
# 3115   netral
#
# [1688 rows x 12 columns]

# %%
df_UpDownSampling['label'].value_counts()
# Out:
# negatif    699
# netral     552
# positif    437
# Name: label, dtype: int64

# %%
import re
import string

nltk.download('punkt')

komentar = df_UpDownSampling['komentar'].astype(str)

#Lower case
komentar = komentar.apply(lambda x: x.lower())

#Remove URL
komentar = komentar.apply(lambda x: re.sub(r'^https?:\/\/.*[\r\n]*', '', x, flags=re.MULTILINE))

#Remove Number
komentar = komentar.apply(lambda x: re.sub(r"\d", "", x))

#Before Punctuation
komentar = komentar.apply(lambda x: re.sub(r'(?<=[,.])(?=[^\s])', r' ', x))

#Punctuation
komentar = komentar.apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

#Remove Non Alphanumeric
komentar = komentar.apply(lambda x: re.sub(r'([^\s\w]|_)+', '', x))

#Tokenizing
komentar = komentar.apply(lambda x: nltk.tokenize.word_tokenize(x))

komentar
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\egapa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 810     [mari, kita, dukung, h, joko, widodo, tetap, m...
# 60                 [kalau, ada, nomor, untuk, apa, nomor]
# 2195    [mantap, lanjut, kan, pak, suara, rakyat, yg, ...
# 1438                                               [amin]
# 1708    [niat, baik, insya, allah, hasilnya, baik, lur...
#                               ...
# 2254                                   [ni, kalo, jomblo]
# 63                               [ke, padang, kapan, pak]
# 3315    [b, foto, nya, itu, lho, idola, mbah, ku, joko...
# 15                                 [duh, gagal, pertamax]
# 3115                                             [bejori]
# Name: komentar, Length: 1688, dtype: object

# %%
model_gensim = FT_gensim(size=300, 
                         negative=5, 
                         min_count=1, 
                         min_n=2, 
                         max_n=3, 
                         sg=0, 
                         sorted_vocab=1, 
                         word_ngrams=1, 
                         window=5, 
                         callbacks=(),
                         ns_exponent=0.75, 
                         cbow_mean=0, 
                         workers=3, 
                         alpha=0.1, 
                         min_alpha=0.025)

# %%
model_gensim.build_vocab(komentar)

# %%
total_examples = model_gensim.corpus_count
model_gensim.train(
    sentences=komentar,
    total_examples=total_examples, 
    epochs = 100
)

# %%
model_gensim.save('XGBUpDownSampling800.bin')
loaded_model = FT_gensim.load('XGBUpDownSampling800.bin')

# %%
loaded_model.wv.similarity("bagus", "jelek")
# Out:
# 0.5519197

# %%
loaded_model.wv.distance("bagus", "jelek")
# Out:
# 0.44808030128479004

# %%
loaded_model.wv.most_similar(positive="jelek", topn=5)
# Out:
# [('dijelekjelekkan', 0.8827989101409912),
#  ('menjelek', 0.8229676485061646),
#  ('elek', 0.7850631475448608),
#  ('menjelekkan', 0.7615231275558472),
#  ('menjelekan', 0.7478713989257812)]

# %%
loaded_model.wv.most_similar_cosmul(positive="bagus", negative=None, topn=5)
# Out:
# [('tokobagus', 0.946358859539032),
#  ('bagusan', 0.9412111639976501),
#  ('gus', 0.9236080646514893),
#  ('bast', 0.9108335971832275),
#  ('bus', 0.9081132411956787)]

# %%
similar_words = {search_term: [item[0] for item in loaded_model.wv.most_similar([search_term], topn=5)]
                for search_term in ['mantap', 'keren', 'bagus', 'jelek', 'parah', 'cepat']}
similar_words
# Out:
# {'mantap': ['mantapkan', 'mantaff', 'mantaf', 'mamtap', 'mantab'],
#  'keren': ['kmren', 'kerena', 'green', 'referendun', 'kabare'],
#  'bagus': ['tokobagus', 'bagusan', 'gus', 'bast', 'bus'],
#  'jelek': ['dijelekjelekkan', 'menjelek', 'elek', 'menjelekkan', 'menjelekan'],
#  'parah': ['para', 'pasrah', 'arah', 'paras', 'payah'],
#  'cepat': ['tepat', 'cepatkan', 'sipat', 'ceplos', 'tmpat']}

# %%
words = sum([[k] + v for k, v in similar_words.items()], [])
wvs = loaded_model.wv[words]

pca = PCA(n_components=2)
np.set_printoptions(suppress=True)
P = pca.fit_transform(wvs)
labels = words

plt.figure(figsize=(20, 10))
plt.scatter(P[:, 0], P[:, 1], c='green', edgecolors='g')
for label, x, y in zip(labels, P[:, 0], P[:, 1]):
    plt.annotate(label, xy=(x+0.06, y+0.03), xytext=(0, 0), textcoords='offset points')
