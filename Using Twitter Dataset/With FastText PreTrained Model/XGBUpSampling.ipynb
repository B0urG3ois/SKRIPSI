# %%
import spacy
import gensim
import pandas as pd
import nltk
import numpy as np
import seaborn as sn
import re
import string
import xgboost as xgb

from xgboost import XGBClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from gensim.models.fasttext import FastText
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from MeanVectorizer import MeanEmbeddingVectorizer
from sklearn.utils import resample

nlp = spacy.blank('id')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\egapa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_excel("dataset_twitter.xlsx")
df.head()
# Out:
#      label                                           komentar
# 0  positif  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 1  positif  Sharing pengalaman aja, kemarin jam 18.00 bata...
# 2  positif  Sharing sama temen tuh emg guna bgt. Disaat lu...
# 3  positif  sangat bersyukur bisa mendoakan kakeknya, Bung...
# 4  positif  H-9. Mau ke bank rame bgt ampe antrian tempat ...

# %%
komentar = df['komentar'].astype(str)

# Huruf kecil
komentar = komentar.apply(lambda x: x.lower())

# Hapus URL
komentar = komentar.apply(lambda x: re.sub(r'^https?:\/\/.*[\r\n]*', '', x, flags=re.MULTILINE))

# Hapus angka
komentar = komentar.apply(lambda x: re.sub(r"\d", "", x))

# Hapus tanda baca
komentar = komentar.apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# Hapus diluar alphabet dan numeric
komentar = komentar.apply(lambda x: re.sub(r'([^\s\w]|_)+', '', x))

# Tokenizing data
komentar = komentar.apply(lambda x: nltk.tokenize.word_tokenize(x))

df['komentar'] = komentar
df
# Out:
#         label                                           komentar
# 0     positif  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 1     positif  [sharing, pengalaman, aja, kemarin, jam, batal...
# 2     positif  [sharing, sama, temen, tuh, emg, guna, bgt, di...
# 3     positif  [sangat, bersyukur, bisa, mendoakan, kakeknya,...
# 4     positif  [h, mau, ke, bank, rame, bgt, ampe, antrian, t...
# ...       ...                                                ...
# 3110   netral  [bukan, saya, yang, tidakmau, merit, sat, ini,...
# 3111   netral  [baru, lihat, kabar, teman, nge, gosip, dan, p...
# 3112   netral  [mengubah, kebiasaan, seseorang, yg, kurang, b...
# 3113   netral  [nah, diam, lebih, bagus, yaudah, saya, diam, ...
# 3114   netral  [ya, allah, hanya, engkau, yang, mengetahui, r...
#
# [3115 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# negatif    1101
# positif    1017
# netral      997
# Name: label, dtype: int64

# %%
df = df[df.komentar.astype(bool)]

df_pos = df[df['label'] == 'positif']
X_pos_text = df_pos['komentar']
y_pos_label = df_pos['label']

df_neg = df[df['label'] == 'negatif']
X_neg_text = df_neg['komentar']
y_neg_label = df_neg['label']

df_net = df[df['label'] == 'netral']
X_net_text = df_net['komentar']
y_net_label = df_net['label']

# %%
X_pos_train, X_pos_test, y_pos_train, y_pos_test = train_test_split(X_pos_text, y_pos_label, test_size=0.2, random_state=1, stratify=y_pos_label)
X_neg_train, X_neg_test, y_neg_train, y_neg_test = train_test_split(X_neg_text, y_neg_label, test_size=0.2, random_state=1, stratify=y_neg_label)
X_net_train, X_net_test, y_net_train, y_net_test = train_test_split(X_net_text, y_net_label, test_size=0.2, random_state=1, stratify=y_net_label)

# %%
X_net_train_up = resample(X_net_train, replace=True, n_samples=int(len(X_pos_train)))
y_net_train_up = resample(y_net_train, replace=True, n_samples=int(len(y_pos_train)))

X_neg_train_up = resample(X_neg_train, replace=True, n_samples=int(len(X_pos_train)))
y_neg_train_up = resample(y_neg_train, replace=True, n_samples=int(len(y_pos_train)))

# %%
X_train = pd.concat([X_pos_train, X_neg_train_up])
X_train = pd.concat([X_train, X_net_train_up])
y_train = pd.concat([y_pos_train, y_neg_train_up])
y_train = pd.concat([y_train, y_net_train_up])

X_test = pd.concat([X_pos_test, X_neg_test])
X_test = pd.concat([X_test, X_net_test])
y_test = pd.concat([y_pos_test, y_neg_test])
y_test = pd.concat([y_test, y_net_test])

# %%
X_train = X_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
print(y_train.value_counts())
# Out:
# netral     813
# positif    813
# negatif    813
# Name: label, dtype: int64

# %%
from gensim.models.fasttext import FastText
model = FastText.load_fasttext_format('../../cc.id.300.bin')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).

# %%
mean_vec_tr = MeanEmbeddingVectorizer(model)

# %%
X_train_vector = mean_vec_tr.transform(X_train)
X_test_vector = mean_vec_tr.transform(X_test)

# %%
lc = preprocessing.LabelEncoder()
lc.fit(y_train)
# Out:
# LabelEncoder()

# %%
y_train_enc=lc.transform(y_train)
y_test_enc=lc.transform(y_test)

# %%
train=xgb.DMatrix(X_train_vector,label=y_train_enc)
test=xgb.DMatrix(X_test_vector,label=y_test_enc)

# %%
param = {}

# Learning Rate:  0.01
# Gamma:  0.5
# Max Depth:  12
# Subsample:  0.4
# Colsample Bytree:  0.3
# Alpha:  0.01
# Lamda:  2
# Min Child Weight:  3
# Number of Trees:  1000

param['num_class']=len(set(y_train))
param['objective'] = 'multi:softmax'
param['learning_rate'] = 0.01
param['gamma'] = 0.5
param['max_depth'] = 12
param['subsample'] = 0.4
param['colsample_bytree'] = 0.3
param['reg_alpha'] = 0.01
param['reg_lambda'] = 2
param['min_child_weight'] = 3
num_round = 1000

watchlist = [(train, 'train'), (test, 'test')]
bst = xgb.train(param, train, num_round, watchlist)
# Out:
# [0]	train-merror:0.30053	test-merror:0.54720
# [1]	train-merror:0.20910	test-merror:0.50400
# [2]	train-merror:0.16400	test-merror:0.51680
# [3]	train-merror:0.14309	test-merror:0.47360
# [4]	train-merror:0.12751	test-merror:0.46880
# [5]	train-merror:0.11029	test-merror:0.45280
# [6]	train-merror:0.10824	test-merror:0.45120
# [7]	train-merror:0.09553	test-merror:0.46080
# [8]	train-merror:0.08815	test-merror:0.43680
# [9]	train-merror:0.08282	test-merror:0.44960
# [10]	train-merror:0.07872	test-merror:0.45280
# [11]	train-merror:0.07667	test-merror:0.45760
# [12]	train-merror:0.07134	test-merror:0.45920
# [13]	train-merror:0.06847	test-merror:0.45120
# [14]	train-merror:0.06232	test-merror:0.44800
# [15]	train-merror:0.06396	test-merror:0.45280
# [16]	train-merror:0.05781	test-merror:0.45280
# [17]	train-merror:0.06232	test-merror:0.44640
# [18]	train-merror:0.05904	test-merror:0.44640
# [19]	train-merror:0.05535	test-merror:0.44800
# [20]	train-merror:0.05699	test-merror:0.43840
# [21]	train-merror:0.05412	test-merror:0.44480
# [22]	train-merror:0.05412	test-merror:0.44160
# [23]	train-merror:0.05125	test-merror:0.43360
# [24]	train-merror:0.05125	test-merror:0.42720
# [25]	train-merror:0.04674	test-merror:0.43360
# [26]	train-merror:0.04715	test-merror:0.43200
# [27]	train-merror:0.04838	test-merror:0.42880
# [28]	train-merror:0.04961	test-merror:0.42080
# [29]	train-merror:0.04756	test-merror:0.42240
# [30]	train-merror:0.04551	test-merror:0.41760
# [31]	train-merror:0.04469	test-merror:0.42080
# [32]	train-merror:0.04592	test-merror:0.41920
# [33]	train-merror:0.04305	test-merror:0.41920
# [34]	train-merror:0.04264	test-merror:0.42240
# [35]	train-merror:0.04264	test-merror:0.41440
# [36]	train-merror:0.04141	test-merror:0.42400
# [37]	train-merror:0.04182	test-merror:0.41920
# [38]	train-merror:0.04100	test-merror:0.42080
# [39]	train-merror:0.04141	test-merror:0.41920
# [40]	train-merror:0.04100	test-merror:0.41280
# [41]	train-merror:0.04264	test-merror:0.40800
# [42]	train-merror:0.04223	test-merror:0.41280
# [43]	train-merror:0.04100	test-merror:0.41280
# [44]	train-merror:0.04387	test-merror:0.41280
# [45]	train-merror:0.03854	test-merror:0.41280
# [46]	train-merror:0.04141	test-merror:0.40800
# [47]	train-merror:0.03977	test-merror:0.41440
# [48]	train-merror:0.03813	test-merror:0.41120
# [49]	train-merror:0.03854	test-merror:0.41120
# [50]	train-merror:0.04100	test-merror:0.41280
# [51]	train-merror:0.03936	test-merror:0.40960
# [52]	train-merror:0.03854	test-merror:0.40800
# [53]	train-merror:0.03772	test-merror:0.39840
# [54]	train-merror:0.03772	test-merror:0.40160
# [55]	train-merror:0.03731	test-merror:0.40480
# [56]	train-merror:0.03526	test-merror:0.40320
# [57]	train-merror:0.03608	test-merror:0.40000
# [58]	train-merror:0.03895	test-merror:0.39840
# [59]	train-merror:0.03649	test-merror:0.40000
# [60]	train-merror:0.03649	test-merror:0.40640
# [61]	train-merror:0.03567	test-merror:0.40800
# [62]	train-merror:0.03444	test-merror:0.40480
# [63]	train-merror:0.03403	test-merror:0.40320
# [64]	train-merror:0.03403	test-merror:0.40160
# [65]	train-merror:0.03280	test-merror:0.40800
# [66]	train-merror:0.03444	test-merror:0.40320
# [67]	train-merror:0.03403	test-merror:0.40800
# [68]	train-merror:0.03403	test-merror:0.40960
# [69]	train-merror:0.03444	test-merror:0.40640
# [70]	train-merror:0.03321	test-merror:0.40160
# [71]	train-merror:0.03362	test-merror:0.40000
# [72]	train-merror:0.03239	test-merror:0.40000
# [73]	train-merror:0.03321	test-merror:0.40320
# [74]	train-merror:0.03157	test-merror:0.40000
# [75]	train-merror:0.02952	test-merror:0.40000
# [76]	train-merror:0.02993	test-merror:0.39680
# [77]	train-merror:0.03116	test-merror:0.39520
# [78]	train-merror:0.03075	test-merror:0.39360
# [79]	train-merror:0.03157	test-merror:0.39360
# [80]	train-merror:0.02952	test-merror:0.40160
# [81]	train-merror:0.02706	test-merror:0.39360
# [82]	train-merror:0.02665	test-merror:0.39200
# [83]	train-merror:0.02747	test-merror:0.39360
# [84]	train-merror:0.02747	test-merror:0.39360
# [85]	train-merror:0.02788	test-merror:0.39040
# [86]	train-merror:0.02583	test-merror:0.39040
# [87]	train-merror:0.02665	test-merror:0.39360
# [88]	train-merror:0.02583	test-merror:0.39680
# [89]	train-merror:0.02624	test-merror:0.39360
# [90]	train-merror:0.02501	test-merror:0.39360
# [91]	train-merror:0.02583	test-merror:0.39200
# [92]	train-merror:0.02665	test-merror:0.39040
# [93]	train-merror:0.02747	test-merror:0.38720
# [94]	train-merror:0.02542	test-merror:0.39040
# [95]	train-merror:0.02583	test-merror:0.38880
# [96]	train-merror:0.02624	test-merror:0.38720
# [97]	train-merror:0.02624	test-merror:0.38880
# [98]	train-merror:0.02583	test-merror:0.38720
# [99]	train-merror:0.02583	test-merror:0.38880
# [100]	train-merror:0.02501	test-merror:0.38560
# [101]	train-merror:0.02460	test-merror:0.38400
# [102]	train-merror:0.02624	test-merror:0.38240
# [103]	train-merror:0.02624	test-merror:0.38560
# [104]	train-merror:0.02583	test-merror:0.38560
# [105]	train-merror:0.02624	test-merror:0.38400
# [106]	train-merror:0.02624	test-merror:0.38080
# [107]	train-merror:0.02583	test-merror:0.38400
# [108]	train-merror:0.02583	test-merror:0.38240
# [109]	train-merror:0.02624	test-merror:0.38240
# [110]	train-merror:0.02583	test-merror:0.38080
# [111]	train-merror:0.02542	test-merror:0.38400
# [112]	train-merror:0.02542	test-merror:0.38720
# [113]	train-merror:0.02460	test-merror:0.38400
# [114]	train-merror:0.02501	test-merror:0.38880
# [115]	train-merror:0.02460	test-merror:0.38720
# [116]	train-merror:0.02460	test-merror:0.38400
# [117]	train-merror:0.02460	test-merror:0.38720
# [118]	train-merror:0.02460	test-merror:0.38240
# [119]	train-merror:0.02460	test-merror:0.38560
# [120]	train-merror:0.02460	test-merror:0.38400
# [121]	train-merror:0.02460	test-merror:0.38720
# [122]	train-merror:0.02419	test-merror:0.39200
# [123]	train-merror:0.02460	test-merror:0.38400
# [124]	train-merror:0.02542	test-merror:0.38240
# [125]	train-merror:0.02460	test-merror:0.38400
# [126]	train-merror:0.02419	test-merror:0.38560
# [127]	train-merror:0.02378	test-merror:0.38880
# [128]	train-merror:0.02296	test-merror:0.39360
# [129]	train-merror:0.02337	test-merror:0.38880
# [130]	train-merror:0.02173	test-merror:0.39360
# [131]	train-merror:0.02091	test-merror:0.39040
# [132]	train-merror:0.02091	test-merror:0.39040
# [133]	train-merror:0.02132	test-merror:0.38720
# [134]	train-merror:0.02091	test-merror:0.38240
# [135]	train-merror:0.02050	test-merror:0.38560
# [136]	train-merror:0.02050	test-merror:0.38560
# [137]	train-merror:0.02132	test-merror:0.38720
# [138]	train-merror:0.01968	test-merror:0.38720
# [139]	train-merror:0.01886	test-merror:0.38560
# [140]	train-merror:0.02009	test-merror:0.38400
# [141]	train-merror:0.01968	test-merror:0.38720
# [142]	train-merror:0.01968	test-merror:0.38400
# [143]	train-merror:0.01804	test-merror:0.38720
# [144]	train-merror:0.01845	test-merror:0.38560
# [145]	train-merror:0.01804	test-merror:0.38560
# [146]	train-merror:0.01763	test-merror:0.38560
# [147]	train-merror:0.01845	test-merror:0.38560
# [148]	train-merror:0.01845	test-merror:0.38560
# [149]	train-merror:0.01886	test-merror:0.38400
# [150]	train-merror:0.01845	test-merror:0.38560
# [151]	train-merror:0.01804	test-merror:0.38560
# [152]	train-merror:0.01763	test-merror:0.38720
# [153]	train-merror:0.01763	test-merror:0.39040
# [154]	train-merror:0.01722	test-merror:0.39040
# [155]	train-merror:0.01763	test-merror:0.38400
# [156]	train-merror:0.01804	test-merror:0.38240
# [157]	train-merror:0.01845	test-merror:0.38560
# [158]	train-merror:0.01886	test-merror:0.38240
# [159]	train-merror:0.01804	test-merror:0.38240
# [160]	train-merror:0.01804	test-merror:0.38560
# [161]	train-merror:0.01886	test-merror:0.38400
# [162]	train-merror:0.01886	test-merror:0.38080
# [163]	train-merror:0.01763	test-merror:0.37760
# [164]	train-merror:0.01722	test-merror:0.37600
# [165]	train-merror:0.01722	test-merror:0.37600
# [166]	train-merror:0.01681	test-merror:0.37600
# [167]	train-merror:0.01558	test-merror:0.38080
# [168]	train-merror:0.01517	test-merror:0.37440
# [169]	train-merror:0.01476	test-merror:0.37760
# [170]	train-merror:0.01640	test-merror:0.37600
# [171]	train-merror:0.01558	test-merror:0.37440
# [172]	train-merror:0.01517	test-merror:0.37440
# [173]	train-merror:0.01558	test-merror:0.37440
# [174]	train-merror:0.01517	test-merror:0.37760
# [175]	train-merror:0.01476	test-merror:0.37760
# [176]	train-merror:0.01517	test-merror:0.37760
# [177]	train-merror:0.01517	test-merror:0.38080
# [178]	train-merror:0.01517	test-merror:0.37760
# [179]	train-merror:0.01517	test-merror:0.37440
# [180]	train-merror:0.01558	test-merror:0.37600
# [181]	train-merror:0.01558	test-merror:0.37600
# [182]	train-merror:0.01558	test-merror:0.38080
# [183]	train-merror:0.01558	test-merror:0.37760
# [184]	train-merror:0.01517	test-merror:0.37920
# [185]	train-merror:0.01517	test-merror:0.37920
# [186]	train-merror:0.01517	test-merror:0.38080
# [187]	train-merror:0.01476	test-merror:0.37760
# [188]	train-merror:0.01435	test-merror:0.37760
# [189]	train-merror:0.01476	test-merror:0.37760
# [190]	train-merror:0.01476	test-merror:0.38080
# [191]	train-merror:0.01476	test-merror:0.38080
# [192]	train-merror:0.01476	test-merror:0.38080
# [193]	train-merror:0.01435	test-merror:0.37920
# [194]	train-merror:0.01394	test-merror:0.37920
# [195]	train-merror:0.01435	test-merror:0.37760
# [196]	train-merror:0.01394	test-merror:0.37760
# [197]	train-merror:0.01394	test-merror:0.37760
# [198]	train-merror:0.01353	test-merror:0.37600
# [199]	train-merror:0.01394	test-merror:0.37600
# [200]	train-merror:0.01394	test-merror:0.38080
# [201]	train-merror:0.01394	test-merror:0.37920
# [202]	train-merror:0.01394	test-merror:0.37600
# [203]	train-merror:0.01435	test-merror:0.37920
# [204]	train-merror:0.01435	test-merror:0.37760
# [205]	train-merror:0.01435	test-merror:0.37600
# [206]	train-merror:0.01435	test-merror:0.37760
# [207]	train-merror:0.01394	test-merror:0.37600
# [208]	train-merror:0.01394	test-merror:0.37920
# [209]	train-merror:0.01394	test-merror:0.37760
# [210]	train-merror:0.01353	test-merror:0.37760
# [211]	train-merror:0.01353	test-merror:0.37760
# [212]	train-merror:0.01353	test-merror:0.37760
# [213]	train-merror:0.01353	test-merror:0.37600
# [214]	train-merror:0.01353	test-merror:0.37600
# [215]	train-merror:0.01353	test-merror:0.37920
# [216]	train-merror:0.01353	test-merror:0.38080
# [217]	train-merror:0.01312	test-merror:0.37760
# [218]	train-merror:0.01353	test-merror:0.37920
# [219]	train-merror:0.01353	test-merror:0.37920
# [220]	train-merror:0.01394	test-merror:0.38080
# [221]	train-merror:0.01353	test-merror:0.38240
# [222]	train-merror:0.01271	test-merror:0.38400
# [223]	train-merror:0.01353	test-merror:0.38400
# [224]	train-merror:0.01271	test-merror:0.38400
# [225]	train-merror:0.01271	test-merror:0.38400
# [226]	train-merror:0.01230	test-merror:0.38080
# [227]	train-merror:0.01271	test-merror:0.38240
# [228]	train-merror:0.01271	test-merror:0.38080
# [229]	train-merror:0.01271	test-merror:0.38240
# [230]	train-merror:0.01271	test-merror:0.38240
# [231]	train-merror:0.01271	test-merror:0.38080
# [232]	train-merror:0.01148	test-merror:0.38400
# [233]	train-merror:0.01107	test-merror:0.38560
# [234]	train-merror:0.01189	test-merror:0.38560
# [235]	train-merror:0.01107	test-merror:0.38400
# [236]	train-merror:0.01025	test-merror:0.38560
# [237]	train-merror:0.01025	test-merror:0.38560
# [238]	train-merror:0.01066	test-merror:0.38560
# [239]	train-merror:0.01066	test-merror:0.38560
# [240]	train-merror:0.01025	test-merror:0.38720
# [241]	train-merror:0.01148	test-merror:0.38720
# [242]	train-merror:0.01066	test-merror:0.38400
# [243]	train-merror:0.01107	test-merror:0.38400
# [244]	train-merror:0.01189	test-merror:0.38560
# [245]	train-merror:0.01230	test-merror:0.38880
# [246]	train-merror:0.01189	test-merror:0.38560
# [247]	train-merror:0.01189	test-merror:0.38560
# [248]	train-merror:0.01107	test-merror:0.38560
# [249]	train-merror:0.01107	test-merror:0.38880
# [250]	train-merror:0.01025	test-merror:0.38560
# [251]	train-merror:0.01066	test-merror:0.38400
# [252]	train-merror:0.01107	test-merror:0.38560
# [253]	train-merror:0.01025	test-merror:0.38560
# [254]	train-merror:0.01107	test-merror:0.38400
# [255]	train-merror:0.01107	test-merror:0.38400
# [256]	train-merror:0.01066	test-merror:0.38400
# [257]	train-merror:0.01107	test-merror:0.38240
# [258]	train-merror:0.01066	test-merror:0.38240
# [259]	train-merror:0.01066	test-merror:0.38560
# [260]	train-merror:0.01066	test-merror:0.38560
# [261]	train-merror:0.01025	test-merror:0.38080
# [262]	train-merror:0.01025	test-merror:0.37920
# [263]	train-merror:0.01025	test-merror:0.38240
# [264]	train-merror:0.01025	test-merror:0.38400
# [265]	train-merror:0.01025	test-merror:0.38240
# [266]	train-merror:0.01066	test-merror:0.38080
# [267]	train-merror:0.01066	test-merror:0.38240
# [268]	train-merror:0.00984	test-merror:0.37920
# [269]	train-merror:0.00984	test-merror:0.38240
# [270]	train-merror:0.00943	test-merror:0.38400
# [271]	train-merror:0.00943	test-merror:0.38240
# [272]	train-merror:0.00984	test-merror:0.38560
# [273]	train-merror:0.00902	test-merror:0.38560
# [274]	train-merror:0.00902	test-merror:0.38400
# [275]	train-merror:0.00902	test-merror:0.38400
# [276]	train-merror:0.00902	test-merror:0.38240
# [277]	train-merror:0.00902	test-merror:0.38400
# [278]	train-merror:0.00820	test-merror:0.38240
# [279]	train-merror:0.00820	test-merror:0.38400
# [280]	train-merror:0.00820	test-merror:0.38400
# [281]	train-merror:0.00820	test-merror:0.37920
# [282]	train-merror:0.00820	test-merror:0.38400
# [283]	train-merror:0.00820	test-merror:0.38240
# [284]	train-merror:0.00820	test-merror:0.38080
# [285]	train-merror:0.00779	test-merror:0.37920
# [286]	train-merror:0.00779	test-merror:0.37760
# [287]	train-merror:0.00738	test-merror:0.37760
# [288]	train-merror:0.00779	test-merror:0.37760
# [289]	train-merror:0.00615	test-merror:0.37760
# [290]	train-merror:0.00697	test-merror:0.37920
# [291]	train-merror:0.00697	test-merror:0.37920
# [292]	train-merror:0.00656	test-merror:0.37600
# [293]	train-merror:0.00697	test-merror:0.37920
# [294]	train-merror:0.00656	test-merror:0.37920
# [295]	train-merror:0.00615	test-merror:0.38080
# [296]	train-merror:0.00656	test-merror:0.38240
# [297]	train-merror:0.00697	test-merror:0.38080
# [298]	train-merror:0.00697	test-merror:0.37920
# [299]	train-merror:0.00697	test-merror:0.37600
# [300]	train-merror:0.00697	test-merror:0.37760
# [301]	train-merror:0.00656	test-merror:0.37760
# [302]	train-merror:0.00656	test-merror:0.37920
# [303]	train-merror:0.00697	test-merror:0.37600
# [304]	train-merror:0.00697	test-merror:0.37760
# [305]	train-merror:0.00697	test-merror:0.37600
# [306]	train-merror:0.00697	test-merror:0.37760
# [307]	train-merror:0.00697	test-merror:0.37760
# [308]	train-merror:0.00615	test-merror:0.37920
# [309]	train-merror:0.00615	test-merror:0.37600
# [310]	train-merror:0.00615	test-merror:0.37600
# [311]	train-merror:0.00656	test-merror:0.37600
# [312]	train-merror:0.00656	test-merror:0.37440
# [313]	train-merror:0.00574	test-merror:0.37280
# [314]	train-merror:0.00574	test-merror:0.37600
# [315]	train-merror:0.00615	test-merror:0.37760
# [316]	train-merror:0.00615	test-merror:0.37600
# [317]	train-merror:0.00574	test-merror:0.37280
# [318]	train-merror:0.00533	test-merror:0.37280
# [319]	train-merror:0.00533	test-merror:0.37280
# [320]	train-merror:0.00533	test-merror:0.37600
# [321]	train-merror:0.00492	test-merror:0.37600
# [322]	train-merror:0.00492	test-merror:0.37760
# [323]	train-merror:0.00492	test-merror:0.37760
# [324]	train-merror:0.00574	test-merror:0.37600
# [325]	train-merror:0.00533	test-merror:0.37600
# [326]	train-merror:0.00533	test-merror:0.37600
# [327]	train-merror:0.00533	test-merror:0.37600
# [328]	train-merror:0.00492	test-merror:0.37600
# [329]	train-merror:0.00492	test-merror:0.37600
# [330]	train-merror:0.00492	test-merror:0.37600
# [331]	train-merror:0.00492	test-merror:0.37600
# [332]	train-merror:0.00492	test-merror:0.37440
# [333]	train-merror:0.00492	test-merror:0.37600
# [334]	train-merror:0.00492	test-merror:0.37440
# [335]	train-merror:0.00533	test-merror:0.37440
# [336]	train-merror:0.00533	test-merror:0.37600
# [337]	train-merror:0.00451	test-merror:0.37600
# [338]	train-merror:0.00492	test-merror:0.37600
# [339]	train-merror:0.00451	test-merror:0.37440
# [340]	train-merror:0.00451	test-merror:0.37440
# [341]	train-merror:0.00451	test-merror:0.36960
# [342]	train-merror:0.00451	test-merror:0.37120
# [343]	train-merror:0.00451	test-merror:0.37280
# [344]	train-merror:0.00451	test-merror:0.37120
# [345]	train-merror:0.00451	test-merror:0.36960
# [346]	train-merror:0.00451	test-merror:0.37280
# [347]	train-merror:0.00451	test-merror:0.37440
# [348]	train-merror:0.00410	test-merror:0.37440
# [349]	train-merror:0.00410	test-merror:0.37120
# [350]	train-merror:0.00410	test-merror:0.36960
# [351]	train-merror:0.00451	test-merror:0.37120
# [352]	train-merror:0.00451	test-merror:0.37440
# [353]	train-merror:0.00451	test-merror:0.37600
# [354]	train-merror:0.00451	test-merror:0.37920
# [355]	train-merror:0.00451	test-merror:0.37440
# [356]	train-merror:0.00492	test-merror:0.37600
# [357]	train-merror:0.00492	test-merror:0.37280
# [358]	train-merror:0.00492	test-merror:0.37280
# [359]	train-merror:0.00492	test-merror:0.37280
# [360]	train-merror:0.00410	test-merror:0.37120
# [361]	train-merror:0.00410	test-merror:0.37120
# [362]	train-merror:0.00410	test-merror:0.37120
# [363]	train-merror:0.00410	test-merror:0.37280
# [364]	train-merror:0.00410	test-merror:0.37280
# [365]	train-merror:0.00410	test-merror:0.37280
# [366]	train-merror:0.00410	test-merror:0.37120
# [367]	train-merror:0.00369	test-merror:0.36960
# [368]	train-merror:0.00369	test-merror:0.36960
# [369]	train-merror:0.00328	test-merror:0.37120
# [370]	train-merror:0.00328	test-merror:0.36960
# [371]	train-merror:0.00328	test-merror:0.37120
# [372]	train-merror:0.00328	test-merror:0.37120
# [373]	train-merror:0.00328	test-merror:0.37120
# [374]	train-merror:0.00369	test-merror:0.36960
# [375]	train-merror:0.00328	test-merror:0.37120
# [376]	train-merror:0.00328	test-merror:0.37120
# [377]	train-merror:0.00287	test-merror:0.37120
# [378]	train-merror:0.00287	test-merror:0.37120
# [379]	train-merror:0.00287	test-merror:0.37120
# [380]	train-merror:0.00287	test-merror:0.37120
# [381]	train-merror:0.00287	test-merror:0.37120
# [382]	train-merror:0.00287	test-merror:0.37120
# [383]	train-merror:0.00287	test-merror:0.37120
# [384]	train-merror:0.00287	test-merror:0.37120
# [385]	train-merror:0.00287	test-merror:0.37120
# [386]	train-merror:0.00287	test-merror:0.37120
# [387]	train-merror:0.00287	test-merror:0.37120
# [388]	train-merror:0.00287	test-merror:0.37120
# [389]	train-merror:0.00287	test-merror:0.36960
# [390]	train-merror:0.00287	test-merror:0.36800
# [391]	train-merror:0.00246	test-merror:0.36800
# [392]	train-merror:0.00287	test-merror:0.36800
# [393]	train-merror:0.00287	test-merror:0.36800
# [394]	train-merror:0.00246	test-merror:0.36800
# [395]	train-merror:0.00246	test-merror:0.36960
# [396]	train-merror:0.00246	test-merror:0.36800
# [397]	train-merror:0.00246	test-merror:0.36960
# [398]	train-merror:0.00246	test-merror:0.36800
# [399]	train-merror:0.00246	test-merror:0.36800
# [400]	train-merror:0.00246	test-merror:0.36800
# [401]	train-merror:0.00246	test-merror:0.36800
# [402]	train-merror:0.00246	test-merror:0.36800
# [403]	train-merror:0.00246	test-merror:0.36800
# [404]	train-merror:0.00246	test-merror:0.36640
# [405]	train-merror:0.00246	test-merror:0.36960
# [406]	train-merror:0.00246	test-merror:0.36800
# [407]	train-merror:0.00246	test-merror:0.36960
# [408]	train-merror:0.00246	test-merror:0.36480
# [409]	train-merror:0.00246	test-merror:0.36480
# [410]	train-merror:0.00246	test-merror:0.36480
# [411]	train-merror:0.00246	test-merror:0.36480
# [412]	train-merror:0.00246	test-merror:0.36480
# [413]	train-merror:0.00246	test-merror:0.36640
# [414]	train-merror:0.00246	test-merror:0.36480
# [415]	train-merror:0.00246	test-merror:0.36480
# [416]	train-merror:0.00246	test-merror:0.36480
# [417]	train-merror:0.00246	test-merror:0.36320
# [418]	train-merror:0.00246	test-merror:0.36480
# [419]	train-merror:0.00246	test-merror:0.36480
# [420]	train-merror:0.00246	test-merror:0.36800
# [421]	train-merror:0.00246	test-merror:0.36800
# [422]	train-merror:0.00246	test-merror:0.36800
# [423]	train-merror:0.00246	test-merror:0.36800
# [424]	train-merror:0.00246	test-merror:0.36800
# [425]	train-merror:0.00246	test-merror:0.36800
# [426]	train-merror:0.00246	test-merror:0.36640
# [427]	train-merror:0.00246	test-merror:0.36800
# [428]	train-merror:0.00246	test-merror:0.36800
# [429]	train-merror:0.00246	test-merror:0.36640
# [430]	train-merror:0.00246	test-merror:0.36640
# [431]	train-merror:0.00246	test-merror:0.36320
# [432]	train-merror:0.00246	test-merror:0.36320
# [433]	train-merror:0.00246	test-merror:0.36320
# [434]	train-merror:0.00246	test-merror:0.36320
# [435]	train-merror:0.00205	test-merror:0.36320
# [436]	train-merror:0.00205	test-merror:0.36320
# [437]	train-merror:0.00164	test-merror:0.36640
# [438]	train-merror:0.00164	test-merror:0.36480
# [439]	train-merror:0.00164	test-merror:0.36480
# [440]	train-merror:0.00164	test-merror:0.36480
# [441]	train-merror:0.00164	test-merror:0.36480
# [442]	train-merror:0.00123	test-merror:0.36640
# [443]	train-merror:0.00164	test-merror:0.36480
# [444]	train-merror:0.00164	test-merror:0.36480
# [445]	train-merror:0.00164	test-merror:0.36480
# [446]	train-merror:0.00164	test-merror:0.36640
# [447]	train-merror:0.00164	test-merror:0.36480
# [448]	train-merror:0.00123	test-merror:0.36640
# [449]	train-merror:0.00164	test-merror:0.36640
# [450]	train-merror:0.00123	test-merror:0.36800
# [451]	train-merror:0.00123	test-merror:0.36800
# [452]	train-merror:0.00123	test-merror:0.36800
# [453]	train-merror:0.00123	test-merror:0.36800
# [454]	train-merror:0.00123	test-merror:0.36960
# [455]	train-merror:0.00123	test-merror:0.36800
# [456]	train-merror:0.00123	test-merror:0.36800
# [457]	train-merror:0.00123	test-merror:0.36960
# [458]	train-merror:0.00123	test-merror:0.36960
# [459]	train-merror:0.00123	test-merror:0.36960
# [460]	train-merror:0.00123	test-merror:0.36800
# [461]	train-merror:0.00123	test-merror:0.36800
# [462]	train-merror:0.00123	test-merror:0.36800
# [463]	train-merror:0.00123	test-merror:0.36800
# [464]	train-merror:0.00123	test-merror:0.36800
# [465]	train-merror:0.00123	test-merror:0.36960
# [466]	train-merror:0.00123	test-merror:0.36640
# [467]	train-merror:0.00123	test-merror:0.36640
# [468]	train-merror:0.00123	test-merror:0.36800
# [469]	train-merror:0.00123	test-merror:0.36800
# [470]	train-merror:0.00123	test-merror:0.36640
# [471]	train-merror:0.00123	test-merror:0.36800
# [472]	train-merror:0.00123	test-merror:0.36480
# [473]	train-merror:0.00123	test-merror:0.36640
# [474]	train-merror:0.00123	test-merror:0.36160
# [475]	train-merror:0.00123	test-merror:0.36160
# [476]	train-merror:0.00123	test-merror:0.36320
# [477]	train-merror:0.00123	test-merror:0.36320
# [478]	train-merror:0.00123	test-merror:0.36320
# [479]	train-merror:0.00123	test-merror:0.36480
# [480]	train-merror:0.00123	test-merror:0.36480
# [481]	train-merror:0.00123	test-merror:0.36640
# [482]	train-merror:0.00123	test-merror:0.36320
# [483]	train-merror:0.00123	test-merror:0.36480
# [484]	train-merror:0.00123	test-merror:0.36320
# [485]	train-merror:0.00123	test-merror:0.36480
# [486]	train-merror:0.00123	test-merror:0.36640
# [487]	train-merror:0.00123	test-merror:0.36320
# [488]	train-merror:0.00123	test-merror:0.36320
# [489]	train-merror:0.00123	test-merror:0.36320
# [490]	train-merror:0.00123	test-merror:0.36480
# [491]	train-merror:0.00123	test-merror:0.36320
# [492]	train-merror:0.00123	test-merror:0.36640
# [493]	train-merror:0.00123	test-merror:0.36640
# [494]	train-merror:0.00123	test-merror:0.36640
# [495]	train-merror:0.00082	test-merror:0.36640
# [496]	train-merror:0.00082	test-merror:0.36640
# [497]	train-merror:0.00082	test-merror:0.36640
# [498]	train-merror:0.00082	test-merror:0.36640
# [499]	train-merror:0.00082	test-merror:0.36640
# [500]	train-merror:0.00082	test-merror:0.36640
# [501]	train-merror:0.00082	test-merror:0.36640
# [502]	train-merror:0.00082	test-merror:0.36640
# [503]	train-merror:0.00082	test-merror:0.36640
# [504]	train-merror:0.00082	test-merror:0.36800
# [505]	train-merror:0.00082	test-merror:0.36640
# [506]	train-merror:0.00082	test-merror:0.36960
# [507]	train-merror:0.00082	test-merror:0.36960
# [508]	train-merror:0.00082	test-merror:0.36960
# [509]	train-merror:0.00082	test-merror:0.37120
# [510]	train-merror:0.00082	test-merror:0.36960
# [511]	train-merror:0.00082	test-merror:0.36640
# [512]	train-merror:0.00082	test-merror:0.36320
# [513]	train-merror:0.00082	test-merror:0.36480
# [514]	train-merror:0.00082	test-merror:0.36480
# [515]	train-merror:0.00082	test-merror:0.36640
# [516]	train-merror:0.00082	test-merror:0.36800
# [517]	train-merror:0.00082	test-merror:0.36480
# [518]	train-merror:0.00082	test-merror:0.36480
# [519]	train-merror:0.00082	test-merror:0.36960
# [520]	train-merror:0.00082	test-merror:0.36640
# [521]	train-merror:0.00082	test-merror:0.36800
# [522]	train-merror:0.00082	test-merror:0.36960
# [523]	train-merror:0.00082	test-merror:0.36800
# [524]	train-merror:0.00082	test-merror:0.36800
# [525]	train-merror:0.00082	test-merror:0.36960
# [526]	train-merror:0.00082	test-merror:0.36960
# [527]	train-merror:0.00082	test-merror:0.36960
# [528]	train-merror:0.00082	test-merror:0.37120
# [529]	train-merror:0.00082	test-merror:0.36960
# [530]	train-merror:0.00082	test-merror:0.36960
# [531]	train-merror:0.00082	test-merror:0.36800
# [532]	train-merror:0.00082	test-merror:0.36800
# [533]	train-merror:0.00082	test-merror:0.36800
# [534]	train-merror:0.00082	test-merror:0.36800
# [535]	train-merror:0.00082	test-merror:0.36800
# [536]	train-merror:0.00082	test-merror:0.36800
# [537]	train-merror:0.00082	test-merror:0.36800
# [538]	train-merror:0.00082	test-merror:0.36800
# [539]	train-merror:0.00082	test-merror:0.36800
# [540]	train-merror:0.00082	test-merror:0.36800
# [541]	train-merror:0.00082	test-merror:0.36800
# [542]	train-merror:0.00082	test-merror:0.36800
# [543]	train-merror:0.00082	test-merror:0.36800
# [544]	train-merror:0.00082	test-merror:0.36800
# [545]	train-merror:0.00082	test-merror:0.36800
# [546]	train-merror:0.00082	test-merror:0.36800
# [547]	train-merror:0.00082	test-merror:0.36800
# [548]	train-merror:0.00082	test-merror:0.36800
# [549]	train-merror:0.00082	test-merror:0.36800
# [550]	train-merror:0.00082	test-merror:0.36800
# [551]	train-merror:0.00082	test-merror:0.36800
# [552]	train-merror:0.00082	test-merror:0.36800
# [553]	train-merror:0.00082	test-merror:0.36800
# [554]	train-merror:0.00082	test-merror:0.36800
# [555]	train-merror:0.00082	test-merror:0.36800
# [556]	train-merror:0.00082	test-merror:0.36800
# [557]	train-merror:0.00082	test-merror:0.36800
# [558]	train-merror:0.00082	test-merror:0.36800
# [559]	train-merror:0.00082	test-merror:0.36800
# [560]	train-merror:0.00082	test-merror:0.36800
# [561]	train-merror:0.00082	test-merror:0.36800
# [562]	train-merror:0.00082	test-merror:0.36640
# [563]	train-merror:0.00082	test-merror:0.36800
# [564]	train-merror:0.00082	test-merror:0.36800
# [565]	train-merror:0.00082	test-merror:0.36800
# [566]	train-merror:0.00082	test-merror:0.36800
# [567]	train-merror:0.00082	test-merror:0.36800
# [568]	train-merror:0.00082	test-merror:0.36640
# [569]	train-merror:0.00082	test-merror:0.36800
# [570]	train-merror:0.00082	test-merror:0.36800
# [571]	train-merror:0.00082	test-merror:0.36800
# [572]	train-merror:0.00082	test-merror:0.36800
# [573]	train-merror:0.00082	test-merror:0.36800
# [574]	train-merror:0.00082	test-merror:0.36800
# [575]	train-merror:0.00082	test-merror:0.36800
# [576]	train-merror:0.00082	test-merror:0.36800
# [577]	train-merror:0.00082	test-merror:0.36800
# [578]	train-merror:0.00082	test-merror:0.36800
# [579]	train-merror:0.00082	test-merror:0.36800
# [580]	train-merror:0.00082	test-merror:0.36960
# [581]	train-merror:0.00082	test-merror:0.37120
# [582]	train-merror:0.00082	test-merror:0.36960
# [583]	train-merror:0.00082	test-merror:0.36800
# [584]	train-merror:0.00082	test-merror:0.36800
# [585]	train-merror:0.00082	test-merror:0.36800
# [586]	train-merror:0.00082	test-merror:0.36800
# [587]	train-merror:0.00082	test-merror:0.36800
# [588]	train-merror:0.00082	test-merror:0.36800
# [589]	train-merror:0.00082	test-merror:0.36800
# [590]	train-merror:0.00082	test-merror:0.36960
# [591]	train-merror:0.00082	test-merror:0.36960
# [592]	train-merror:0.00082	test-merror:0.36960
# [593]	train-merror:0.00082	test-merror:0.36960
# [594]	train-merror:0.00082	test-merror:0.37120
# [595]	train-merror:0.00082	test-merror:0.36960
# [596]	train-merror:0.00082	test-merror:0.36960
# [597]	train-merror:0.00082	test-merror:0.36960
# [598]	train-merror:0.00082	test-merror:0.36800
# [599]	train-merror:0.00082	test-merror:0.36640
# [600]	train-merror:0.00082	test-merror:0.36800
# [601]	train-merror:0.00082	test-merror:0.36800
# [602]	train-merror:0.00082	test-merror:0.36800
# [603]	train-merror:0.00082	test-merror:0.36960
# [604]	train-merror:0.00082	test-merror:0.36960
# [605]	train-merror:0.00082	test-merror:0.36960
# [606]	train-merror:0.00082	test-merror:0.36960
# [607]	train-merror:0.00082	test-merror:0.36960
# [608]	train-merror:0.00082	test-merror:0.36960
# [609]	train-merror:0.00082	test-merror:0.37120
# [610]	train-merror:0.00082	test-merror:0.36960
# [611]	train-merror:0.00082	test-merror:0.36960
# [612]	train-merror:0.00082	test-merror:0.36960
# [613]	train-merror:0.00082	test-merror:0.36960
# [614]	train-merror:0.00082	test-merror:0.36960
# [615]	train-merror:0.00082	test-merror:0.36960
# [616]	train-merror:0.00082	test-merror:0.36960
# [617]	train-merror:0.00082	test-merror:0.36960
# [618]	train-merror:0.00082	test-merror:0.36800
# [619]	train-merror:0.00082	test-merror:0.36800
# [620]	train-merror:0.00082	test-merror:0.36800
# [621]	train-merror:0.00082	test-merror:0.36800
# [622]	train-merror:0.00082	test-merror:0.36800
# [623]	train-merror:0.00082	test-merror:0.36640
# [624]	train-merror:0.00082	test-merror:0.36800
# [625]	train-merror:0.00082	test-merror:0.36640
# [626]	train-merror:0.00082	test-merror:0.36800
# [627]	train-merror:0.00082	test-merror:0.36800
# [628]	train-merror:0.00082	test-merror:0.36800
# [629]	train-merror:0.00082	test-merror:0.36960
# [630]	train-merror:0.00082	test-merror:0.36960
# [631]	train-merror:0.00082	test-merror:0.36960
# [632]	train-merror:0.00082	test-merror:0.37120
# [633]	train-merror:0.00082	test-merror:0.37120
# [634]	train-merror:0.00082	test-merror:0.36960
# [635]	train-merror:0.00082	test-merror:0.36960
# [636]	train-merror:0.00082	test-merror:0.36960
# [637]	train-merror:0.00082	test-merror:0.36960
# [638]	train-merror:0.00082	test-merror:0.36960
# [639]	train-merror:0.00082	test-merror:0.36800
# [640]	train-merror:0.00082	test-merror:0.36960
# [641]	train-merror:0.00082	test-merror:0.36800
# [642]	train-merror:0.00082	test-merror:0.36800
# [643]	train-merror:0.00082	test-merror:0.36800
# [644]	train-merror:0.00082	test-merror:0.36800
# [645]	train-merror:0.00082	test-merror:0.36640
# [646]	train-merror:0.00082	test-merror:0.36640
# [647]	train-merror:0.00082	test-merror:0.36640
# [648]	train-merror:0.00082	test-merror:0.36640
# [649]	train-merror:0.00082	test-merror:0.36640
# [650]	train-merror:0.00082	test-merror:0.36640
# [651]	train-merror:0.00082	test-merror:0.36640
# [652]	train-merror:0.00082	test-merror:0.36320
# [653]	train-merror:0.00082	test-merror:0.36320
# [654]	train-merror:0.00082	test-merror:0.36480
# [655]	train-merror:0.00082	test-merror:0.36640
# [656]	train-merror:0.00082	test-merror:0.36640
# [657]	train-merror:0.00082	test-merror:0.36640
# [658]	train-merror:0.00082	test-merror:0.36640
# [659]	train-merror:0.00082	test-merror:0.36640
# [660]	train-merror:0.00082	test-merror:0.36640
# [661]	train-merror:0.00082	test-merror:0.36640
# [662]	train-merror:0.00082	test-merror:0.36640
# [663]	train-merror:0.00082	test-merror:0.36640
# [664]	train-merror:0.00082	test-merror:0.36640
# [665]	train-merror:0.00082	test-merror:0.36960
# [666]	train-merror:0.00082	test-merror:0.36960
# [667]	train-merror:0.00082	test-merror:0.36640
# [668]	train-merror:0.00082	test-merror:0.36800
# [669]	train-merror:0.00082	test-merror:0.36640
# [670]	train-merror:0.00082	test-merror:0.36800
# [671]	train-merror:0.00082	test-merror:0.36640
# [672]	train-merror:0.00082	test-merror:0.36640
# [673]	train-merror:0.00082	test-merror:0.36640
# [674]	train-merror:0.00082	test-merror:0.36640
# [675]	train-merror:0.00082	test-merror:0.36480
# [676]	train-merror:0.00082	test-merror:0.36480
# [677]	train-merror:0.00082	test-merror:0.36640
# [678]	train-merror:0.00082	test-merror:0.36640
# [679]	train-merror:0.00082	test-merror:0.36640
# [680]	train-merror:0.00082	test-merror:0.36640
# [681]	train-merror:0.00082	test-merror:0.36800
# [682]	train-merror:0.00082	test-merror:0.36480
# [683]	train-merror:0.00082	test-merror:0.36640
# [684]	train-merror:0.00082	test-merror:0.36480
# [685]	train-merror:0.00082	test-merror:0.36640
# [686]	train-merror:0.00082	test-merror:0.36480
# [687]	train-merror:0.00082	test-merror:0.36480
# [688]	train-merror:0.00082	test-merror:0.36480
# [689]	train-merror:0.00082	test-merror:0.36640
# [690]	train-merror:0.00082	test-merror:0.36480
# [691]	train-merror:0.00082	test-merror:0.36480
# [692]	train-merror:0.00082	test-merror:0.36480
# [693]	train-merror:0.00082	test-merror:0.36480
# [694]	train-merror:0.00082	test-merror:0.36480
# [695]	train-merror:0.00082	test-merror:0.36480
# [696]	train-merror:0.00082	test-merror:0.36320
# [697]	train-merror:0.00082	test-merror:0.36480
# [698]	train-merror:0.00082	test-merror:0.36480
# [699]	train-merror:0.00082	test-merror:0.36320
# [700]	train-merror:0.00082	test-merror:0.36480
# [701]	train-merror:0.00082	test-merror:0.36480
# [702]	train-merror:0.00082	test-merror:0.36480
# [703]	train-merror:0.00082	test-merror:0.36480
# [704]	train-merror:0.00082	test-merror:0.36480
# [705]	train-merror:0.00082	test-merror:0.36480
# [706]	train-merror:0.00082	test-merror:0.36480
# [707]	train-merror:0.00082	test-merror:0.36480
# [708]	train-merror:0.00082	test-merror:0.36480
# [709]	train-merror:0.00082	test-merror:0.36480
# [710]	train-merror:0.00082	test-merror:0.36640
# [711]	train-merror:0.00082	test-merror:0.36640
# [712]	train-merror:0.00082	test-merror:0.36640
# [713]	train-merror:0.00082	test-merror:0.36640
# [714]	train-merror:0.00082	test-merror:0.36640
# [715]	train-merror:0.00082	test-merror:0.36640
# [716]	train-merror:0.00082	test-merror:0.36480
# [717]	train-merror:0.00082	test-merror:0.36640
# [718]	train-merror:0.00082	test-merror:0.36640
# [719]	train-merror:0.00082	test-merror:0.36640
# [720]	train-merror:0.00082	test-merror:0.36480
# [721]	train-merror:0.00082	test-merror:0.36640
# [722]	train-merror:0.00082	test-merror:0.36640
# [723]	train-merror:0.00082	test-merror:0.36640
# [724]	train-merror:0.00082	test-merror:0.36640
# [725]	train-merror:0.00082	test-merror:0.36640
# [726]	train-merror:0.00082	test-merror:0.36640
# [727]	train-merror:0.00082	test-merror:0.36640
# [728]	train-merror:0.00082	test-merror:0.36480
# [729]	train-merror:0.00082	test-merror:0.36480
# [730]	train-merror:0.00082	test-merror:0.36640
# [731]	train-merror:0.00082	test-merror:0.36640
# [732]	train-merror:0.00082	test-merror:0.36640
# [733]	train-merror:0.00082	test-merror:0.36640
# [734]	train-merror:0.00082	test-merror:0.36480
# [735]	train-merror:0.00082	test-merror:0.36480
# [736]	train-merror:0.00082	test-merror:0.36640
# [737]	train-merror:0.00082	test-merror:0.36640
# [738]	train-merror:0.00082	test-merror:0.36640
# [739]	train-merror:0.00082	test-merror:0.36480
# [740]	train-merror:0.00082	test-merror:0.36320
# [741]	train-merror:0.00082	test-merror:0.36480
# [742]	train-merror:0.00082	test-merror:0.36320
# [743]	train-merror:0.00082	test-merror:0.36320
# [744]	train-merror:0.00082	test-merror:0.36160
# [745]	train-merror:0.00082	test-merror:0.36160
# [746]	train-merror:0.00082	test-merror:0.36160
# [747]	train-merror:0.00082	test-merror:0.36000
# [748]	train-merror:0.00082	test-merror:0.36000
# [749]	train-merror:0.00082	test-merror:0.36000
# [750]	train-merror:0.00082	test-merror:0.36000
# [751]	train-merror:0.00082	test-merror:0.36000
# [752]	train-merror:0.00082	test-merror:0.36000
# [753]	train-merror:0.00082	test-merror:0.36000
# [754]	train-merror:0.00082	test-merror:0.35840
# [755]	train-merror:0.00082	test-merror:0.36160
# [756]	train-merror:0.00082	test-merror:0.35840
# [757]	train-merror:0.00082	test-merror:0.35840
# [758]	train-merror:0.00082	test-merror:0.36000
# [759]	train-merror:0.00082	test-merror:0.36160
# [760]	train-merror:0.00082	test-merror:0.35840
# [761]	train-merror:0.00082	test-merror:0.35680
# [762]	train-merror:0.00082	test-merror:0.35840
# [763]	train-merror:0.00082	test-merror:0.35840
# [764]	train-merror:0.00082	test-merror:0.36160
# [765]	train-merror:0.00082	test-merror:0.36160
# [766]	train-merror:0.00082	test-merror:0.36160
# [767]	train-merror:0.00082	test-merror:0.36160
# [768]	train-merror:0.00082	test-merror:0.36160
# [769]	train-merror:0.00082	test-merror:0.36160
# [770]	train-merror:0.00082	test-merror:0.36160
# [771]	train-merror:0.00082	test-merror:0.36160
# [772]	train-merror:0.00082	test-merror:0.36160
# [773]	train-merror:0.00082	test-merror:0.36160
# [774]	train-merror:0.00082	test-merror:0.36160
# [775]	train-merror:0.00082	test-merror:0.36320
# [776]	train-merror:0.00082	test-merror:0.36320
# [777]	train-merror:0.00082	test-merror:0.36320
# [778]	train-merror:0.00082	test-merror:0.36480
# [779]	train-merror:0.00082	test-merror:0.36320
# [780]	train-merror:0.00082	test-merror:0.36480
# [781]	train-merror:0.00082	test-merror:0.36480
# [782]	train-merror:0.00082	test-merror:0.36480
# [783]	train-merror:0.00082	test-merror:0.36480
# [784]	train-merror:0.00082	test-merror:0.36480
# [785]	train-merror:0.00082	test-merror:0.36320
# [786]	train-merror:0.00082	test-merror:0.36160
# [787]	train-merror:0.00082	test-merror:0.36480
# [788]	train-merror:0.00082	test-merror:0.36320
# [789]	train-merror:0.00082	test-merror:0.36320
# [790]	train-merror:0.00082	test-merror:0.36480
# [791]	train-merror:0.00082	test-merror:0.36480
# [792]	train-merror:0.00082	test-merror:0.36160
# [793]	train-merror:0.00082	test-merror:0.36160
# [794]	train-merror:0.00082	test-merror:0.36320
# [795]	train-merror:0.00082	test-merror:0.36320
# [796]	train-merror:0.00082	test-merror:0.36320
# [797]	train-merror:0.00082	test-merror:0.36320
# [798]	train-merror:0.00082	test-merror:0.36320
# [799]	train-merror:0.00082	test-merror:0.36320
# [800]	train-merror:0.00082	test-merror:0.36160
# [801]	train-merror:0.00082	test-merror:0.36160
# [802]	train-merror:0.00082	test-merror:0.36160
# [803]	train-merror:0.00082	test-merror:0.36000
# [804]	train-merror:0.00082	test-merror:0.36000
# [805]	train-merror:0.00082	test-merror:0.36000
# [806]	train-merror:0.00082	test-merror:0.35840
# [807]	train-merror:0.00082	test-merror:0.36000
# [808]	train-merror:0.00082	test-merror:0.35840
# [809]	train-merror:0.00082	test-merror:0.35840
# [810]	train-merror:0.00082	test-merror:0.35840
# [811]	train-merror:0.00082	test-merror:0.35680
# [812]	train-merror:0.00082	test-merror:0.35840
# [813]	train-merror:0.00082	test-merror:0.35680
# [814]	train-merror:0.00082	test-merror:0.35840
# [815]	train-merror:0.00082	test-merror:0.36000
# [816]	train-merror:0.00082	test-merror:0.35840
# [817]	train-merror:0.00082	test-merror:0.35840
# [818]	train-merror:0.00041	test-merror:0.35840
# [819]	train-merror:0.00041	test-merror:0.35840
# [820]	train-merror:0.00041	test-merror:0.35840
# [821]	train-merror:0.00041	test-merror:0.35840
# [822]	train-merror:0.00041	test-merror:0.35840
# [823]	train-merror:0.00041	test-merror:0.35840
# [824]	train-merror:0.00041	test-merror:0.35840
# [825]	train-merror:0.00041	test-merror:0.35840
# [826]	train-merror:0.00041	test-merror:0.35840
# [827]	train-merror:0.00041	test-merror:0.35680
# [828]	train-merror:0.00041	test-merror:0.35840
# [829]	train-merror:0.00041	test-merror:0.36000
# [830]	train-merror:0.00041	test-merror:0.35680
# [831]	train-merror:0.00041	test-merror:0.35680
# [832]	train-merror:0.00041	test-merror:0.35680
# [833]	train-merror:0.00041	test-merror:0.35840
# [834]	train-merror:0.00041	test-merror:0.35840
# [835]	train-merror:0.00041	test-merror:0.35840
# [836]	train-merror:0.00041	test-merror:0.35840
# [837]	train-merror:0.00041	test-merror:0.35840
# [838]	train-merror:0.00041	test-merror:0.35680
# [839]	train-merror:0.00041	test-merror:0.35680
# [840]	train-merror:0.00041	test-merror:0.35680
# [841]	train-merror:0.00041	test-merror:0.35680
# [842]	train-merror:0.00041	test-merror:0.35840
# [843]	train-merror:0.00041	test-merror:0.35680
# [844]	train-merror:0.00041	test-merror:0.35680
# [845]	train-merror:0.00041	test-merror:0.35520
# [846]	train-merror:0.00041	test-merror:0.35200
# [847]	train-merror:0.00041	test-merror:0.35360
# [848]	train-merror:0.00041	test-merror:0.35680
# [849]	train-merror:0.00041	test-merror:0.35520
# [850]	train-merror:0.00041	test-merror:0.35680
# [851]	train-merror:0.00041	test-merror:0.35520
# [852]	train-merror:0.00041	test-merror:0.35840
# [853]	train-merror:0.00041	test-merror:0.36000
# [854]	train-merror:0.00041	test-merror:0.36000
# [855]	train-merror:0.00041	test-merror:0.36160
# [856]	train-merror:0.00041	test-merror:0.36000
# [857]	train-merror:0.00041	test-merror:0.35840
# [858]	train-merror:0.00041	test-merror:0.36000
# [859]	train-merror:0.00041	test-merror:0.35840
# [860]	train-merror:0.00041	test-merror:0.36000
# [861]	train-merror:0.00041	test-merror:0.36480
# [862]	train-merror:0.00041	test-merror:0.36480
# [863]	train-merror:0.00041	test-merror:0.36320
# [864]	train-merror:0.00041	test-merror:0.36160
# [865]	train-merror:0.00041	test-merror:0.36320
# [866]	train-merror:0.00041	test-merror:0.36160
# [867]	train-merror:0.00000	test-merror:0.36160
# [868]	train-merror:0.00000	test-merror:0.36320
# [869]	train-merror:0.00000	test-merror:0.36160
# [870]	train-merror:0.00000	test-merror:0.36000
# [871]	train-merror:0.00000	test-merror:0.36000
# [872]	train-merror:0.00000	test-merror:0.36160
# [873]	train-merror:0.00000	test-merror:0.36160
# [874]	train-merror:0.00000	test-merror:0.36160
# [875]	train-merror:0.00000	test-merror:0.36160
# [876]	train-merror:0.00000	test-merror:0.36320
# [877]	train-merror:0.00000	test-merror:0.36000
# [878]	train-merror:0.00000	test-merror:0.36160
# [879]	train-merror:0.00000	test-merror:0.36000
# [880]	train-merror:0.00000	test-merror:0.36320
# [881]	train-merror:0.00000	test-merror:0.36160
# [882]	train-merror:0.00000	test-merror:0.36160
# [883]	train-merror:0.00000	test-merror:0.36000
# [884]	train-merror:0.00000	test-merror:0.36160
# [885]	train-merror:0.00000	test-merror:0.36160
# [886]	train-merror:0.00000	test-merror:0.36160
# [887]	train-merror:0.00000	test-merror:0.36160
# [888]	train-merror:0.00000	test-merror:0.36160
# [889]	train-merror:0.00000	test-merror:0.36160
# [890]	train-merror:0.00000	test-merror:0.36160
# [891]	train-merror:0.00000	test-merror:0.36160
# [892]	train-merror:0.00000	test-merror:0.36160
# [893]	train-merror:0.00000	test-merror:0.36320
# [894]	train-merror:0.00000	test-merror:0.36320
# [895]	train-merror:0.00000	test-merror:0.36320
# [896]	train-merror:0.00000	test-merror:0.36320
# [897]	train-merror:0.00000	test-merror:0.36320
# [898]	train-merror:0.00000	test-merror:0.36320
# [899]	train-merror:0.00000	test-merror:0.36160
# [900]	train-merror:0.00000	test-merror:0.36160
# [901]	train-merror:0.00000	test-merror:0.36320
# [902]	train-merror:0.00000	test-merror:0.36320
# [903]	train-merror:0.00000	test-merror:0.36160
# [904]	train-merror:0.00000	test-merror:0.36160
# [905]	train-merror:0.00000	test-merror:0.36160
# [906]	train-merror:0.00000	test-merror:0.36160
# [907]	train-merror:0.00000	test-merror:0.36160
# [908]	train-merror:0.00000	test-merror:0.36160
# [909]	train-merror:0.00000	test-merror:0.36160
# [910]	train-merror:0.00000	test-merror:0.36160
# [911]	train-merror:0.00000	test-merror:0.36160
# [912]	train-merror:0.00000	test-merror:0.36160
# [913]	train-merror:0.00000	test-merror:0.36160
# [914]	train-merror:0.00000	test-merror:0.36160
# [915]	train-merror:0.00000	test-merror:0.36160
# [916]	train-merror:0.00000	test-merror:0.36160
# [917]	train-merror:0.00000	test-merror:0.36160
# [918]	train-merror:0.00000	test-merror:0.36160
# [919]	train-merror:0.00000	test-merror:0.36160
# [920]	train-merror:0.00000	test-merror:0.36160
# [921]	train-merror:0.00000	test-merror:0.36160
# [922]	train-merror:0.00000	test-merror:0.36160
# [923]	train-merror:0.00000	test-merror:0.36320
# [924]	train-merror:0.00000	test-merror:0.36320
# [925]	train-merror:0.00000	test-merror:0.36160
# [926]	train-merror:0.00000	test-merror:0.36160
# [927]	train-merror:0.00000	test-merror:0.36160
# [928]	train-merror:0.00000	test-merror:0.36160
# [929]	train-merror:0.00000	test-merror:0.36160
# [930]	train-merror:0.00000	test-merror:0.36160
# [931]	train-merror:0.00000	test-merror:0.36160
# [932]	train-merror:0.00000	test-merror:0.36160
# [933]	train-merror:0.00000	test-merror:0.36160
# [934]	train-merror:0.00000	test-merror:0.36160
# [935]	train-merror:0.00000	test-merror:0.36160
# [936]	train-merror:0.00000	test-merror:0.36160
# [937]	train-merror:0.00000	test-merror:0.36160
# [938]	train-merror:0.00000	test-merror:0.36160
# [939]	train-merror:0.00000	test-merror:0.36160
# [940]	train-merror:0.00000	test-merror:0.36160
# [941]	train-merror:0.00000	test-merror:0.36160
# [942]	train-merror:0.00000	test-merror:0.36160
# [943]	train-merror:0.00000	test-merror:0.36160
# [944]	train-merror:0.00000	test-merror:0.36160
# [945]	train-merror:0.00000	test-merror:0.36000
# [946]	train-merror:0.00000	test-merror:0.36000
# [947]	train-merror:0.00000	test-merror:0.36000
# [948]	train-merror:0.00000	test-merror:0.36000
# [949]	train-merror:0.00000	test-merror:0.36000
# [950]	train-merror:0.00000	test-merror:0.36000
# [951]	train-merror:0.00000	test-merror:0.36000
# [952]	train-merror:0.00000	test-merror:0.36000
# [953]	train-merror:0.00000	test-merror:0.36000
# [954]	train-merror:0.00000	test-merror:0.36160
# [955]	train-merror:0.00000	test-merror:0.36000
# [956]	train-merror:0.00000	test-merror:0.36000
# [957]	train-merror:0.00000	test-merror:0.36000
# [958]	train-merror:0.00000	test-merror:0.36000
# [959]	train-merror:0.00000	test-merror:0.36000
# [960]	train-merror:0.00000	test-merror:0.36160
# [961]	train-merror:0.00000	test-merror:0.36160
# [962]	train-merror:0.00000	test-merror:0.36160
# [963]	train-merror:0.00000	test-merror:0.36000
# [964]	train-merror:0.00000	test-merror:0.36000
# [965]	train-merror:0.00000	test-merror:0.36000
# [966]	train-merror:0.00000	test-merror:0.36000
# [967]	train-merror:0.00000	test-merror:0.35840
# [968]	train-merror:0.00000	test-merror:0.35840
# [969]	train-merror:0.00000	test-merror:0.35840
# [970]	train-merror:0.00000	test-merror:0.35680
# [971]	train-merror:0.00000	test-merror:0.35840
# [972]	train-merror:0.00000	test-merror:0.36160
# [973]	train-merror:0.00000	test-merror:0.36000
# [974]	train-merror:0.00000	test-merror:0.36160
# [975]	train-merror:0.00000	test-merror:0.36160
# [976]	train-merror:0.00000	test-merror:0.36000
# [977]	train-merror:0.00000	test-merror:0.36160
# [978]	train-merror:0.00000	test-merror:0.36000
# [979]	train-merror:0.00000	test-merror:0.36000
# [980]	train-merror:0.00000	test-merror:0.36000
# [981]	train-merror:0.00000	test-merror:0.36000
# [982]	train-merror:0.00000	test-merror:0.36000
# [983]	train-merror:0.00000	test-merror:0.36000
# [984]	train-merror:0.00000	test-merror:0.36000
# [985]	train-merror:0.00000	test-merror:0.36000
# [986]	train-merror:0.00000	test-merror:0.35840
# [987]	train-merror:0.00000	test-merror:0.35840
# [988]	train-merror:0.00000	test-merror:0.35840
# [989]	train-merror:0.00000	test-merror:0.35840
# [990]	train-merror:0.00000	test-merror:0.35840
# [991]	train-merror:0.00000	test-merror:0.35840
# [992]	train-merror:0.00000	test-merror:0.35840
# [993]	train-merror:0.00000	test-merror:0.35840
# [994]	train-merror:0.00000	test-merror:0.35840
# [995]	train-merror:0.00000	test-merror:0.35840
# [996]	train-merror:0.00000	test-merror:0.35840
# [997]	train-merror:0.00000	test-merror:0.36000
# [998]	train-merror:0.00000	test-merror:0.36000
# [999]	train-merror:0.00000	test-merror:0.36000

# %%
pred = bst.predict(test)
pred2 = bst.predict(train)

# %%
predictions = lc.inverse_transform(list(map(int,pred)))
predictions2 = lc.inverse_transform(list(map(int,pred2)))

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

test_score = accuracy_score(predictions,y_test)
train_score = accuracy_score(predictions2, y_train)

print("\nTest Score\n", test_score, "\n")
print("Train Score\n", train_score, "\n")
print("CONFUSSION MATRIX\n", confusion_matrix(y_test, predictions), "\n")
print("CLASSIFICATION REPORT\n", classification_report(y_test, predictions), "\n")
# Out:
# Test Score
#  0.64
#
# Train Score
#  1.0
#
# CONFUSSION MATRIX
#  [[150  31  40]
#  [ 43  95  62]
#  [ 25  24 155]]
#
# CLASSIFICATION REPORT
#                precision    recall  f1-score   support
#
#      negatif       0.69      0.68      0.68       221
#       netral       0.63      0.47      0.54       200
#      positif       0.60      0.76      0.67       204
#
#     accuracy                           0.64       625
#    macro avg       0.64      0.64      0.63       625
# weighted avg       0.64      0.64      0.63       625

# %%
import seaborn as sn

confusion = pd.crosstab(y_test, predictions, rownames=['Actual'], colnames=['Predicted'])

sn.heatmap(confusion, annot=True)

# %%
# # Create XGB Classifier object
# xgb_clf = xgb.XGBClassifier(tree_method = "exact", predictor = "gpu_predictor", verbosity = 1, objective = "multi:softmax")

# Create parameter grid
# {"learning_rate": [0.1, 0.01, 0.001],
#                "gamma" : [0.01, 0.1, 0.3, 0.5, 1, 1.5, 2],
#                "max_depth": [2, 4, 7, 10],
#                "colsample_bytree": [0.3, 0.6, 0.8, 1.0],
#                "subsample": [0.2, 0.4, 0.5, 0.6, 0.7],
#                "reg_alpha": [0, 0.5, 1],
#                "reg_lambda": [1, 1.5, 2, 3, 4.5],
#                "min_child_weight": [1, 3, 5, 7],
#                "n_estimators": [100, 250, 500, 1000]}

# parameters = {"learning_rate": [0.001, 0.01, 0.1, 0.4],
#                "gamma" : [0.01, 0.1, 0.3, 0.5, 1, 1.5, 2],
#                "max_depth": [2, 4, 7, 10, 12],
#                "colsample_bytree": [0.3, 0.6, 0.8, 1.0],
#                "subsample": [0.2, 0.4, 0.5, 0.6, 0.7],
#                "reg_alpha": [0.001, 0.01, 0.025, 0.5, 1],
#                "reg_lambda": [1, 1.5, 2, 3, 4.5],
#                "min_child_weight": [1, 3, 5, 7],
#                "n_estimators": [100, 250, 500, 1000]}

# from sklearn.model_selection import RandomizedSearchCV
# # Create RandomizedSearchCV Object
# xgb_rscv = RandomizedSearchCV(xgb_clf, param_distributions = parameters, scoring = "f1_micro",
#                              cv = 10, verbose = 3, random_state = 40 )
           
# # Fit the model
# model_xgboost = xgb_rscv.fit(X_train_vector, y_train)

# # Model best estimators
# print("Learning Rate: ", model_xgboost.best_estimator_.get_params()["learning_rate"])
# print("Gamma: ", model_xgboost.best_estimator_.get_params()["gamma"])
# print("Max Depth: ", model_xgboost.best_estimator_.get_params()["max_depth"])
# print("Subsample: ", model_xgboost.best_estimator_.get_params()["subsample"])
# print("Colsample Bytree: ", model_xgboost.best_estimator_.get_params()["colsample_bytree"])
# print("Alpha: ", model_xgboost.best_estimator_.get_params()["reg_alpha"])
# print("Lamda: ", model_xgboost.best_estimator_.get_params()["reg_lambda"])
# print("Min Child Weight: ", model_xgboost.best_estimator_.get_params()["min_child_weight"])
# print("Number of Trees: ", model_xgboost.best_estimator_.get_params()["n_estimators"])
